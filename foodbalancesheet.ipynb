# %%
import pandas as pd 
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# The dataset is provided by the Food and Agriculture Organization of the United Nations

# %%
df = pd.read_csv("FoodBalanceSheets_E_Africa_NOFLAG.csv", encoding = 'latin-1')
df
# Out:
#        Area Code      Area  Item Code                      Item  Element Code  \
# 0              4   Algeria       2501                Population           511
# 1              4   Algeria       2501                Population          5301
# 2              4   Algeria       2901               Grand Total           664
# 3              4   Algeria       2901               Grand Total           674
# 4              4   Algeria       2901               Grand Total           684
# 5              4   Algeria       2903          Vegetal Products           664
# 6              4   Algeria       2903          Vegetal Products           674
# 7              4   Algeria       2903          Vegetal Products           684
# 8              4   Algeria       2941           Animal Products           664
# 9              4   Algeria       2941           Animal Products           674
# 10             4   Algeria       2941           Animal Products           684
# ...

# %%
df.shape
# Out:
# (60943, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60943 entries, 0 to 60942
# Data columns (total 12 columns):
# Area Code       60943 non-null int64
# Area            60943 non-null object
# Item Code       60943 non-null int64
# Item            60943 non-null object
# Element Code    60943 non-null int64
# Element         60943 non-null object
# Unit            60943 non-null object
# Y2014           59354 non-null float64
# Y2015           59395 non-null float64
# Y2016           59408 non-null float64
# Y2017           59437 non-null float64
# Y2018           59507 non-null float64
# dtypes: float64(5), int64(3), object(4)
# memory usage: 4.6+ MB

# %%
df.describe()
# Out:
#           Area Code     Item Code  Element Code          Y2014          Y2015  \
# count  60943.000000  60943.000000  60943.000000   59354.000000   59395.000000
# mean     134.265576   2687.176706   3814.856456     134.196282     135.235966
# std       72.605709    146.055739   2212.007033    1567.663696    1603.403984
# min        4.000000   2501.000000    511.000000   -1796.000000   -3161.000000
# 25%       74.000000   2562.000000    684.000000       0.000000       0.000000
# 50%      136.000000   2630.000000   5142.000000       0.090000       0.080000
# 75%      195.000000   2775.000000   5511.000000       8.340000       8.460000
# max      276.000000   2961.000000   5911.000000  176405.000000  181137.000000
#
#                Y2016          Y2017          Y2018
# count   59408.000000   59437.000000   59507.000000
# mean      136.555222     140.917765     143.758381
# std      1640.007194    1671.862359    1710.782658
# min     -3225.000000   -1582.000000   -3396.000000
# ...

# %%
df.isnull()["Y2014"].value_counts()
# Out:
# False    59354
# True      1589
# Name: Y2014, dtype: int64

# %%
df.isnull()["Y2015"].value_counts()
# Out:
# False    59395
# True      1548
# Name: Y2015, dtype: int64

# %%
df.isnull()["Y2016"].value_counts()
# Out:
# False    59408
# True      1535
# Name: Y2016, dtype: int64

# %%
df.isnull()["Y2017"].value_counts()
# Out:
# False    59437
# True      1506
# Name: Y2017, dtype: int64

# %%
df.isnull()["Y2018"].value_counts()
# Out:
# False    59507
# True      1436
# Name: Y2018, dtype: int64

# %%
plt.figure(figsize = (12,6))
sns.heatmap(df.isnull())

# %%
df.columns
# Out:
# Index(['Area Code', 'Area', 'Item Code', 'Item', 'Element Code', 'Element',
#        'Unit', 'Y2014', 'Y2015', 'Y2016', 'Y2017', 'Y2018'],
#       dtype='object')

# %%
df['Area'].nunique()
# Out:
# 49

# %%
df['Item'].nunique()
# Out:
# 119

# %%
df.corr()
# Out:
#               Area Code  Item Code  Element Code     Y2014     Y2015  \
# Area Code      1.000000  -0.005159     -0.000209  0.006164  0.005472
# Item Code     -0.005159   1.000000     -0.024683  0.021722  0.020857
# Element Code  -0.000209  -0.024683      1.000000  0.024457  0.023889
# Y2014          0.006164   0.021722      0.024457  1.000000  0.994647
# Y2015          0.005472   0.020857      0.023889  0.994647  1.000000
# Y2016          0.005247   0.020109      0.023444  0.996081  0.995739
# Y2017          0.005006   0.021494      0.024254  0.995230  0.988048
# Y2018          0.005665   0.021314      0.024279  0.994872  0.988208
#
#                  Y2016     Y2017     Y2018
# Area Code     0.005247  0.005006  0.005665
# Item Code     0.020109  0.021494  0.021314
# Element Code  0.023444  0.024254  0.024279
# Y2014         0.996081  0.995230  0.994872
# Y2015         0.995739  0.988048  0.988208
# Y2016         1.000000  0.992785  0.992757
# ...

# %%
sns.heatmap(df.corr(), annot = True)

# %%
df.columns
# Out:
# Index(['Area Code', 'Area', 'Item Code', 'Item', 'Element Code', 'Element',
#        'Unit', 'Y2014', 'Y2015', 'Y2016', 'Y2017', 'Y2018'],
#       dtype='object')

# %%
a_y = df[['Area', 'Y2017']]
a_y.groupby('Area').sum()
# Out:
#                                   Y2017
# Area
# Algeria                       325644.27
# Angola                        229159.57
# Benin                         124771.22
# Botswana                       22101.30
# Burkina Faso                  101855.07
# Cabo Verde                     14650.74
# Cameroon                      232030.43
# Central African Republic       29937.00
# Chad                           71594.68
# Comoros                           59.84
# Congo                          41181.68
# Côte d'Ivoire                 224599.01
# Djibouti                       22729.91
# Egypt                         866379.92
# Eswatini                       54343.33
# Ethiopia                      448683.76
# Ethiopia PDR                       0.00
# Gabon                          27979.64
# Gambia                         23154.18
# Ghana                         337599.06
# Guinea                         98138.87
# Guinea-Bissau                  19102.77
# ...

# %%
df.head()
# Out:
#    Area Code     Area  Item Code         Item  Element Code  \
# 0          4  Algeria       2501   Population           511
# 1          4  Algeria       2501   Population          5301
# 2          4  Algeria       2901  Grand Total           664
# 3          4  Algeria       2901  Grand Total           674
# 4          4  Algeria       2901  Grand Total           684
#
#                                   Element             Unit     Y2014  \
# 0           Total Population - Both sexes     1000 persons  38924.00
# 1                Domestic supply quantity      1000 tonnes      0.00
# 2           Food supply (kcal/capita/day)  kcal/capita/day   3377.00
# 3  Protein supply quantity (g/capita/day)     g/capita/day     94.90
# 4      Fat supply quantity (g/capita/day)     g/capita/day     80.06
#
#       Y2015     Y2016     Y2017     Y2018
# 0  39728.00  40551.00  41389.00  42228.00
# 1      0.00      0.00      0.00      0.00
# 2   3379.00   3372.00   3341.00   3322.00
# ...

# %%
df.columns
# Out:
# Index(['Area Code', 'Area', 'Item Code', 'Item', 'Element Code', 'Element',
#        'Unit', 'Y2014', 'Y2015', 'Y2016', 'Y2017', 'Y2018'],
#       dtype='object')

# %%
df.groupby('Element').sum()
# Out:
#                                         Area Code  Item Code  Element Code  \
# Element
# Domestic supply quantity                   708993   14197445      28068795
# Export Quantity                            599910   11840553      26026133
# Fat supply quantity (g/capita/day)         675050   13535000       3435732
# Feed                                       176272    3538507       7282199
# Food                                       663295   13285035      25406622
# Food supply (kcal/capita/day)              674057   13511060       3329296
# Food supply quantity (kg/capita/yr)        658446   13185401       3163725
# Import Quantity                            688174   13795966      28834929
# Losses                                     274353    5424803      10292107
# Other uses (non-food)                      235554    4729749       8926728
# Processing                                 271940    5350416      10313310
# ...

# %%
madagas = df.query("Element == 'Protein supply quantity (g/capita/day)'")

# %%
madagas.groupby('Area').sum()
# Out:
#                              Area Code  Item Code  Element Code   Y2014  \
# Area
# Algeria                            432     291489         72792  379.56
# Angola                             791     304356         76162  231.66
# Benin                             5777     293767         73466  275.28
# Botswana                          2260     304560         76162  275.18
# Burkina Faso                     26329     304269         76162  321.31
# Cabo Verde                        3640     280998         70096  276.71
# Cameroon                          3680     309693         77510  287.66
# Central African Republic          4181     304086         76162  175.05
# Chad                              4290     296797         74140  254.70
# Congo                             5198     304663         76162  207.55
# Côte d'Ivoire                    12412     312274         78184  221.81
# Djibouti                          7272     273345         68074  256.89
# ...

# %%
madagas.columns
# Out:
# Index(['Area Code', 'Area', 'Item Code', 'Item', 'Element Code', 'Element',
#        'Unit', 'Y2014', 'Y2015', 'Y2016', 'Y2017', 'Y2018'],
#       dtype='object')

# %%
madag = madagas[['Area', 'Y2015']]
madag.groupby('Area').sum()
# Out:
#                               Y2015
# Area
# Algeria                      377.37
# Angola                       214.15
# Benin                        271.97
# Botswana                     278.52
# Burkina Faso                 317.99
# Cabo Verde                   278.41
# Cameroon                     291.53
# Central African Republic     173.70
# Chad                         252.28
# Congo                        227.08
# Côte d'Ivoire                232.59
# Djibouti                     269.59
# Egypt                        394.87
# Eswatini                     237.71
# Ethiopia                     259.82
# Gabon                        345.41
# Gambia                       257.67
# Ghana                        241.71
# Guinea                       227.46
# Guinea-Bissau                168.61
# Kenya                        251.73
# Lesotho                      254.50
# Liberia                      159.43
# Madagascar                   173.05
# Malawi                       272.49
# ...

# %%
df.head()
df.columns
# Out:
# Index(['Area Code', 'Area', 'Item Code', 'Item', 'Element Code', 'Element',
#        'Unit', 'Y2014', 'Y2015', 'Y2016', 'Y2017', 'Y2018'],
#       dtype='object')

# %%
df.groupby('Item').sum()
# Out:
#                           Area Code  Item Code  Element Code      Y2014  \
# Item
# Alcohol, Non-Food             38447     752497       1515090    2403.00
# Alcoholic Beverages           75016    1649136       2171381  102410.11
# Animal Products               18060     397035         90990   11935.65
# Animal fats                   85279    1882494       2567303  209460.54
# Apples and products           69280    1352989       1920418    9499.23
# Aquatic Animals, Others       47420     966381       1139179      14.55
# Aquatic Plants                51178    1057275       1278386     507.29
# Aquatic Products, Other       52570    1160712       1320249     519.62
# Bananas                       68496    1338880       1894890   53267.31
# Barley and products           76321    1432410       2243002   25384.66
# Beans                         78001    1476680       2263509   19207.68
# Beer                          65975    1314720       1813728   41879.92
# ...

# %%
element = df.groupby('Element').sum()
element
# Out:
#                                         Area Code  Item Code  Element Code  \
# Element
# Domestic supply quantity                   708993   14197445      28068795
# Export Quantity                            599910   11840553      26026133
# Fat supply quantity (g/capita/day)         675050   13535000       3435732
# Feed                                       176272    3538507       7282199
# Food                                       663295   13285035      25406622
# Food supply (kcal/capita/day)              674057   13511060       3329296
# Food supply quantity (kg/capita/yr)        658446   13185401       3163725
# Import Quantity                            688174   13795966      28834929
# Losses                                     274353    5424803      10292107
# Other uses (non-food)                      235554    4729749       8926728
# Processing                                 271940    5350416      10313310
# ...

# %%
element.loc['Stock Variation']
# Out:
# Area Code         571566.00
# Item Code       11329527.00
# Element Code    21464704.00
# Y2014              58749.83
# Y2015              34910.99
# Y2016              33140.12
# Y2017              54316.91
# Y2018              20577.91
# Name: Stock Variation, dtype: float64

# %%
element.loc['Processing']
# Out:
# Area Code         271940.0
# Item Code        5350416.0
# Element Code    10313310.0
# Y2014             282923.0
# Y2015             287929.0
# Y2016             280631.0
# Y2017             292836.0
# Y2018             308429.0
# Name: Processing, dtype: float64
