# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df = pd.read_csv("FoodBalanceSheets_E_Africa_NOFLAG.csv", encoding = "Latin-1")
df.head()
# Out:
#    Area Code     Area  Item Code         Item  Element Code  \
# 0          4  Algeria       2501   Population           511
# 1          4  Algeria       2501   Population          5301
# 2          4  Algeria       2901  Grand Total           664
# 3          4  Algeria       2901  Grand Total           674
# 4          4  Algeria       2901  Grand Total           684
#
#                                   Element             Unit     Y2014  \
# 0           Total Population - Both sexes     1000 persons  38924.00
# 1                Domestic supply quantity      1000 tonnes      0.00
# 2           Food supply (kcal/capita/day)  kcal/capita/day   3377.00
# 3  Protein supply quantity (g/capita/day)     g/capita/day     94.90
# 4      Fat supply quantity (g/capita/day)     g/capita/day     80.06
#
#       Y2015     Y2016     Y2017     Y2018
# 0  39728.00  40551.00  41389.00  42228.00
# 1      0.00      0.00      0.00      0.00
# 2   3379.00   3372.00   3341.00   3322.00
# ...

# %%
len(df["Element Code"].unique())
# Out:
# 18

# %%
df.iloc[6:100]
# Out:
#     Area Code     Area  Item Code                      Item  Element Code  \
# 6           4  Algeria       2903          Vegetal Products           674
# 7           4  Algeria       2903          Vegetal Products           684
# 8           4  Algeria       2941           Animal Products           664
# 9           4  Algeria       2941           Animal Products           674
# 10          4  Algeria       2941           Animal Products           684
# 11          4  Algeria       2905  Cereals - Excluding Beer          5511
# 12          4  Algeria       2905  Cereals - Excluding Beer          5611
# 13          4  Algeria       2905  Cereals - Excluding Beer          5072
# 14          4  Algeria       2905  Cereals - Excluding Beer          5911
# 15          4  Algeria       2905  Cereals - Excluding Beer          5301
# 16          4  Algeria       2905  Cereals - Excluding Beer          5521
# 17          4  Algeria       2905  Cereals - Excluding Beer          5527
# ...

# %%
df.describe()
# Out:
#           Area Code     Item Code  Element Code          Y2014          Y2015  \
# count  60943.000000  60943.000000  60943.000000   59354.000000   59395.000000
# mean     134.265576   2687.176706   3814.856456     134.196282     135.235966
# std       72.605709    146.055739   2212.007033    1567.663696    1603.403984
# min        4.000000   2501.000000    511.000000   -1796.000000   -3161.000000
# 25%       74.000000   2562.000000    684.000000       0.000000       0.000000
# 50%      136.000000   2630.000000   5142.000000       0.090000       0.080000
# 75%      195.000000   2775.000000   5511.000000       8.340000       8.460000
# max      276.000000   2961.000000   5911.000000  176405.000000  181137.000000
#
#                Y2016          Y2017          Y2018
# count   59408.000000   59437.000000   59507.000000
# mean      136.555222     140.917765     143.758381
# std      1640.007194    1671.862359    1710.782658
# min     -3225.000000   -1582.000000   -3396.000000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60943 entries, 0 to 60942
# Data columns (total 12 columns):
# Area Code       60943 non-null int64
# Area            60943 non-null object
# Item Code       60943 non-null int64
# Item            60943 non-null object
# Element Code    60943 non-null int64
# Element         60943 non-null object
# Unit            60943 non-null object
# Y2014           59354 non-null float64
# Y2015           59395 non-null float64
# Y2016           59408 non-null float64
# Y2017           59437 non-null float64
# Y2018           59507 non-null float64
# dtypes: float64(5), int64(3), object(4)
# memory usage: 4.6+ MB

# %%
df['Y2017']
# Out:
# 0        41389.00
# 1            0.00
# 2         3341.00
# 3           92.82
# 4           80.19
# 5         2921.00
# 6           66.11
# 7           55.59
# 8          421.00
# 9           26.71
# 10          24.60
# 11        3478.00
# 12       13039.00
# 13         705.00
# 14          10.00
# 15       15803.00
# 16        4667.00
# 17         202.00
# 18        1121.00
# 19          33.00
# 20         840.00
# 21           0.00
# 22        8941.00
# 23         216.02
# 24        1656.00
# 25          48.86
# 26           6.63
# 27        2437.00
# 28        8105.00
# 29         546.00
#            ...
# 60913       15.00
# 60914       -4.00
# 60915        1.00
# 60916       19.00
# 60917        0.00
# 60918       19.00
# 60919        1.34
# 60920        2.00
# 60921        0.05
# 60922        0.02
# 60923        0.00
# 60924        0.00
# 60925        0.00
# 60926        0.00
# 60927        0.00
# 60928        0.00
# 60929        0.00
# 60930        0.00
# 60931        0.00
# ...

# %%
df.isnull().sum()
# Out:
# Area Code          0
# Area               0
# Item Code          0
# Item               0
# Element Code       0
# Element            0
# Unit               0
# Y2014           1589
# Y2015           1548
# Y2016           1535
# Y2017           1506
# Y2018           1436
# dtype: int64

# %%
df.corr()
# Out:
#               Area Code  Item Code  Element Code     Y2014     Y2015  \
# Area Code      1.000000  -0.005159     -0.000209  0.006164  0.005472
# Item Code     -0.005159   1.000000     -0.024683  0.021722  0.020857
# Element Code  -0.000209  -0.024683      1.000000  0.024457  0.023889
# Y2014          0.006164   0.021722      0.024457  1.000000  0.994647
# Y2015          0.005472   0.020857      0.023889  0.994647  1.000000
# Y2016          0.005247   0.020109      0.023444  0.996081  0.995739
# Y2017          0.005006   0.021494      0.024254  0.995230  0.988048
# Y2018          0.005665   0.021314      0.024279  0.994872  0.988208
#
#                  Y2016     Y2017     Y2018
# Area Code     0.005247  0.005006  0.005665
# Item Code     0.020109  0.021494  0.021314
# Element Code  0.023444  0.024254  0.024279
# Y2014         0.996081  0.995230  0.994872
# Y2015         0.995739  0.988048  0.988208
# Y2016         1.000000  0.992785  0.992757
# ...

# %%
df.columns
# Out:
# Index(['Area Code', 'Area', 'Item Code', 'Item', 'Element Code', 'Element',
#        'Unit', 'Y2014', 'Y2015', 'Y2016', 'Y2017', 'Y2018'],
#       dtype='object')

# %%
byArea = df.groupby('Area')
byArea.describe()
# Out:
#                             Area Code                                          \
#                                 count   mean  std    min    25%    50%    75%
# Area
# Algeria                        1313.0    4.0  0.0    4.0    4.0    4.0    4.0
# Angola                         1424.0    7.0  0.0    7.0    7.0    7.0    7.0
# Benin                          1285.0   53.0  0.0   53.0   53.0   53.0   53.0
# Botswana                       1378.0   20.0  0.0   20.0   20.0   20.0   20.0
# Burkina Faso                   1409.0  233.0  0.0  233.0  233.0  233.0  233.0
# Cabo Verde                     1260.0   35.0  0.0   35.0   35.0   35.0   35.0
# Cameroon                       1460.0   32.0  0.0   32.0   32.0   32.0   32.0
# Central African Republic       1344.0   37.0  0.0   37.0   37.0   37.0   37.0
# Chad                           1343.0   39.0  0.0   39.0   39.0   39.0   39.0
# Comoros                          45.0   45.0  0.0   45.0   45.0   45.0   45.0
# ...

# %%
len(df["Area"].unique())
# Out:
# 49

# %%
byArea = df.groupby('Area')
byArea.describe().loc['Madagascar', 'Y2015'].transpose()
# Out:
# count     1429.000000
# mean        88.645836
# std        754.979551
# min       -305.000000
# 25%          0.000000
# 50%          0.020000
# 75%          7.000000
# max      24234.000000
# Name: Madagascar, dtype: float64

# %%
byArea = df.groupby('Area')
byArea.describe().loc[['Egypt', 'South Africa', 'Kenya', 'Nigeria', 'Ethiopia'], 'Y2017' ]
# Out:
#                count         mean          std     min  25%    50%      75%  \
# Area
# Egypt         1458.0   594.224911  3560.771316 -1582.0  0.0  1.225  47.0000
# South Africa  1395.0   371.032645  2194.696940  -144.0  0.0  3.000  55.5000
# Kenya         1548.0   170.969419  1408.584749  -186.0  0.0  0.610  17.0000
# Nigeria       1457.0  1018.028984  7642.098415  -694.0  0.0  0.680  61.0000
# Ethiopia      1428.0   314.204314  3122.142176  -792.0  0.0  0.130  18.1075
#
#                    max
# Area
# Egypt          96443.0
# South Africa   57010.0
# Kenya          50221.0
# Nigeria       190873.0
# Ethiopia      106400.0

# %%
df["Area"].unique()
# Out:
# array(['Algeria', 'Angola', 'Benin', 'Botswana', 'Burkina Faso',
#        'Cabo Verde', 'Cameroon', 'Central African Republic', 'Chad',
#        'Comoros', 'Congo', "Côte d'Ivoire", 'Djibouti', 'Egypt',
#        'Eswatini', 'Ethiopia', 'Ethiopia PDR', 'Gabon', 'Gambia', 'Ghana',
#        'Guinea', 'Guinea-Bissau', 'Kenya', 'Lesotho', 'Liberia',
#        'Madagascar', 'Malawi', 'Mali', 'Mauritania', 'Mauritius',
#        'Morocco', 'Mozambique', 'Namibia', 'Niger', 'Nigeria', 'Rwanda',
#        'Sao Tome and Principe', 'Senegal', 'Seychelles', 'Sierra Leone',
#        'South Africa', 'Sudan', 'Sudan (former)', 'Togo', 'Tunisia',
#        'Uganda', 'United Republic of Tanzania', 'Zambia', 'Zimbabwe'],
#       dtype=object)

# %%
df.shape
# Out:
# (60943, 12)
